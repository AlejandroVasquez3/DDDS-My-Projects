# %% [markdown]
# <a href="https://colab.research.google.com/github/AlejandroVasquez3/DDDS-My-Projects/blob/main/Project-2/Project_2_Housing_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Title

# %% [markdown]
# ## Problem Definition

# %% [markdown]
# - Supervied learning
# - Regression
# - Target being sales price
#   - numerical
#  - The goal is to
#
# State the business problem. Translate the business problem into a Data Science problem by stating what kind of problem it is ( supervised vs unsupervised ) and whether it is a classification, regression, or clustering problem.

# %% [markdown]
# ## Data Collection/Sources

# %%
# Importing needed libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
from sklearn import datasets, metrics, model_selection
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, classification_report, mean_squared_error

# %%
url =  "https://ddc-datascience.s3.amazonaws.com/Projects/Project.2-Housing/Data/Housing.Data.csv"
pdf_url = "/content/housing_data_dictionary.csv"

# %%
# !curl -s -I -XHEAD {url}
# Out:
# HTTP/1.1 200 OK
# x-amz-id-2: 5BZfj1DuMoj7ecakDr8HXrjTZJD4atKQfZ20mKP4GXEZCiwH/1/ngB7JCQdamt5jq+AMeE0KabPJLYDhi1oY04ZKWJmI9W++6/uGEOxWHLg=
# x-amz-request-id: 59W21HV42N7AHY3W
# Date: Wed, 18 Jun 2025 16:37:21 GMT
# Last-Modified: Fri, 06 Oct 2023 04:00:27 GMT
# ETag: "76e84c9ee7f6fd4d51276697f81e76e1"
# x-amz-server-side-encryption: AES256
# Accept-Ranges: bytes
# Content-Type: text/csv
# Content-Length: 880420
# Server: AmazonS3

# %%
# !curl -s -O {url}

# %%
# !ls -la
# Out:
# total 876
# drwxr-xr-x 1 root root   4096 Jun 18 16:37 .
# drwxr-xr-x 1 root root   4096 Jun 18 16:35 ..
# drwxr-xr-x 4 root root   4096 Jun 17 13:36 .config
# -rw-r--r-- 1 root root 880420 Jun 18 16:37 Housing.Data.csv
# drwxr-xr-x 1 root root   4096 Jun 17 13:37 sample_data

# %% [markdown]
# #### Housing Data

# %%
housing_data = pd.read_csv(url)
print(housing_data.shape)
# Out:
# (2637, 81)

# %%
housing_data_copy = housing_data.copy()

# %% [markdown]
# ## Data Cleaning

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2637 entries, 0 to 2636
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PID              2637 non-null   int64
#  1   MS SubClass      2637 non-null   int64
#  2   MS Zoning        2637 non-null   object
#  3   Lot Frontage     2188 non-null   float64
#  4   Lot Area         2637 non-null   int64
#  5   Street           2637 non-null   object
#  6   Alley            180 non-null    object
#  7   Lot Shape        2637 non-null   object
#  8   Land Contour     2637 non-null   object
#  9   Utilities        2637 non-null   object
#  10  Lot Config       2637 non-null   object
#  11  Land Slope       2637 non-null   object
#  12  Neighborhood     2637 non-null   object
#  13  Condition 1      2637 non-null   object
#  14  Condition 2      2637 non-null   object
#  15  Bldg Type        2637 non-null   object
#  16  House Style      2637 non-null   object
#  17  Overall Qual     2637 non-null   int64
#  18  Overall Cond     2637 non-null   int64
#  19  Year Built       2637 non-null   int64
#  20  Year Remod/Add   2637 non-null   int64
#  21  Roof Style       2637 non-null   object
#  22  Roof Matl        2637 non-null   object
#  23  Exterior 1st     2637 non-null   object
#  24  Exterior 2nd     2637 non-null   object
#  25  Mas Vnr Type     1030 non-null   object
#  26  Mas Vnr Area     2614 non-null   float64
#  27  Exter Qual       2637 non-null   object
#  28  Exter Cond       2637 non-null   object
#  29  Foundation       2637 non-null   object
#  30  Bsmt Qual        2564 non-null   object
#  31  Bsmt Cond        2564 non-null   object
#  32  Bsmt Exposure    2561 non-null   object
#  33  BsmtFin Type 1   2564 non-null   object
#  34  BsmtFin SF 1     2636 non-null   float64
#  35  BsmtFin Type 2   2563 non-null   object
#  36  BsmtFin SF 2     2636 non-null   float64
#  37  Bsmt Unf SF      2636 non-null   float64
#  38  Total Bsmt SF    2636 non-null   float64
#  39  Heating          2637 non-null   object
#  40  Heating QC       2637 non-null   object
#  41  Central Air      2637 non-null   object
#  42  Electrical       2637 non-null   object
#  43  1st Flr SF       2637 non-null   int64
#  44  2nd Flr SF       2637 non-null   int64
#  45  Low Qual Fin SF  2637 non-null   int64
#  46  Gr Liv Area      2637 non-null   int64
#  47  Bsmt Full Bath   2635 non-null   float64
#  48  Bsmt Half Bath   2635 non-null   float64
#  49  Full Bath        2637 non-null   int64
#  50  Half Bath        2637 non-null   int64
#  51  Bedroom AbvGr    2637 non-null   int64
#  52  Kitchen AbvGr    2637 non-null   int64
#  53  Kitchen Qual     2637 non-null   object
#  54  TotRms AbvGrd    2637 non-null   int64
#  55  Functional       2637 non-null   object
#  56  Fireplaces       2637 non-null   int64
#  57  Fireplace Qu     1353 non-null   object
#  58  Garage Type      2492 non-null   object
#  59  Garage Yr Blt    2490 non-null   float64
#  60  Garage Finish    2490 non-null   object
#  61  Garage Cars      2636 non-null   float64
#  62  Garage Area      2636 non-null   float64
#  63  Garage Qual      2490 non-null   object
#  64  Garage Cond      2490 non-null   object
#  65  Paved Drive      2637 non-null   object
#  66  Wood Deck SF     2637 non-null   int64
#  67  Open Porch SF    2637 non-null   int64
#  68  Enclosed Porch   2637 non-null   int64
#  69  3Ssn Porch       2637 non-null   int64
#  70  Screen Porch     2637 non-null   int64
#  71  Pool Area        2637 non-null   int64
#  72  Pool QC          11 non-null     object
#  73  Fence            528 non-null    object
#  74  Misc Feature     96 non-null     object
#  75  Misc Val         2637 non-null   int64
#  76  Mo Sold          2637 non-null   int64
#  77  Yr Sold          2637 non-null   int64
#  78  Sale Type        2637 non-null   object
#  79  Sale Condition   2637 non-null   object
#  80  SalePrice        2637 non-null   int64
# dtypes: float64(11), int64(27), object(43)
# memory usage: 1.6+ MB

# %%
(
    housing_data
      .describe()
      .transpose()
      .query("count < 2637")
      .sort_values("count")
)
# Out:
#                  count         mean         std     min      25%     50%  \
# Lot Frontage    2188.0    69.166819   23.356779    21.0    58.00    68.0
# Garage Yr Blt   2490.0  1978.185944   25.452647  1895.0  1961.00  1979.0
# Mas Vnr Area    2614.0   101.887911  179.578232     0.0     0.00     0.0
# Bsmt Full Bath  2635.0     0.432258    0.525239     0.0     0.00     0.0
# Bsmt Half Bath  2635.0     0.058824    0.240130     0.0     0.00     0.0
# BsmtFin SF 2    2636.0    51.068665  172.521803     0.0     0.00     0.0
# Total Bsmt SF   2636.0  1045.179059  429.686089     0.0   792.00   988.0
# BsmtFin SF 1    2636.0   438.441199  449.602326     0.0     0.00   368.0
# Bsmt Unf SF     2636.0   555.669196  436.223188     0.0   218.00   464.5
# Garage Cars     2636.0     1.763278    0.760576     0.0     1.00     2.0
# Garage Area     2636.0   470.968134  212.816905     0.0   324.75   480.0
#
#                     75%     max
# Lot Frontage      80.00   313.0
# Garage Yr Blt   2002.00  2207.0
# Mas Vnr Area     164.00  1600.0
# Bsmt Full Bath     1.00     3.0
# Bsmt Half Bath     0.00     2.0
# BsmtFin SF 2       0.00  1526.0
# Total Bsmt SF   1290.25  6110.0
# BsmtFin SF 1     732.00  5644.0
# Bsmt Unf SF      797.25  2336.0
# Garage Cars        2.00     5.0
# Garage Area      576.00  1488.0

# %%
housing_data.dtypes.value_counts()
# Out:
# object     43
# int64      27
# float64    11
# Name: count, dtype: int64

# %%
# Finding columns with 2 or less uniqie variables
foo = housing_data.nunique()
foo [foo<=2]
# Out:
# Street         2
# Alley          2
# Central Air    2
# dtype: int64

# %% [markdown]
# ### Checking NaN and Zeros in Rows

# %% [markdown]
# ### Checking NaN and Zeros in Columns

# %%
# Finding the columns with NaN and print the list made
nan_columns = []
for column in housing_data.columns:
  if housing_data[column].isna().any():
    nan_columns.append(column)
print(f"Columns with NaN: {nan_columns}")
print(f"Total Columns with NaN: {len(nan_columns)}")
# Out:
# Columns with NaN: ['Lot Frontage', 'Alley', 'Mas Vnr Type', 'Mas Vnr Area', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Fireplace Qu', 'Garage Type', 'Garage Yr Blt', 'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual', 'Garage Cond', 'Pool QC', 'Fence', 'Misc Feature']
# Total Columns with NaN: 26

# %%
# Finding the columns with Zeros and print the list made
zero_columns = []
for column in housing_data.columns:
  if (housing_data[column] == 0).any():
    zero_columns.append(column)
print(f"Columns with Zeros: {zero_columns}")
print(f"Total Columns with Zeros: {len(zero_columns)}")
# Out:
# Columns with Zeros: ['Mas Vnr Area', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF', '2nd Flr SF', 'Low Qual Fin SF', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Fireplaces', 'Garage Cars', 'Garage Area', 'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Misc Val']
# Total Columns with Zeros: 23

# %%
housing_data.columns
# Out:
# Index(['PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area', 'Street',
#        'Alley', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config',
#        'Land Slope', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type',
#        'House Style', 'Overall Qual', 'Overall Cond', 'Year Built',
#        'Year Remod/Add', 'Roof Style', 'Roof Matl', 'Exterior 1st',
#        'Exterior 2nd', 'Mas Vnr Type', 'Mas Vnr Area', 'Exter Qual',
#        'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin Type 2', 'BsmtFin SF 2',
#        'Bsmt Unf SF', 'Total Bsmt SF', 'Heating', 'Heating QC', 'Central Air',
#        'Electrical', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF',
#        'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath',
#        'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual',
#        'TotRms AbvGrd', 'Functional', 'Fireplaces', 'Fireplace Qu',
#        'Garage Type', 'Garage Yr Blt', 'Garage Finish', 'Garage Cars',
#        'Garage Area', 'Garage Qual', 'Garage Cond', 'Paved Drive',
#        'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch',
#        'Screen Porch', 'Pool Area', 'Pool QC', 'Fence', 'Misc Feature',
#        'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type', 'Sale Condition',
#        'SalePrice'],
#       dtype='object')

# %% [markdown]
# ### Float Data Frame

# %%
# Data frame of float values
housing_data_float = housing_data.select_dtypes(include=["float"])
# Sales price data series
housing_data_salesprice = housing_data['SalePrice']#.astype("float")
# Combining data frames
housing_data__float_test = pd.concat([housing_data_float, housing_data_salesprice], axis = 1)

housing_data__float_test.head(10)
# housing_data__float_test.info()
# Out:
#    Lot Frontage  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  Bsmt Unf SF  \
# 0          62.0           0.0         513.0         144.0        348.0
# 1          72.0           0.0           0.0           0.0          0.0
# 2          50.0           0.0           0.0           0.0        780.0
# 3          68.0           0.0         484.0           0.0        491.0
# 4          60.0           0.0         350.0         210.0          0.0
# 5          70.0           0.0         842.0           0.0         70.0
# 6          64.0          82.0         724.0           0.0        508.0
# 7          66.0           0.0           0.0           0.0       1163.0
# 8           NaN           0.0         735.0           0.0        257.0
# 9          40.0           0.0         370.0           0.0        779.0
#
#    Total Bsmt SF  Bsmt Full Bath  Bsmt Half Bath  Garage Yr Blt  Garage Cars  \
# 0         1005.0             1.0             0.0         1964.0          2.0
# 1            0.0             0.0             0.0         1967.0          2.0
# 2          780.0             0.0             0.0         1979.0          1.0
# 3          975.0             1.0             0.0         2000.0          2.0
# 4          560.0             1.0             0.0         1971.0          2.0
# 5          912.0             0.0             0.0         1974.0          1.0
# 6         1232.0             1.0             0.0         2007.0          2.0
# 7         1163.0             0.0             0.0         1955.0          2.0
# 8          992.0             1.0             0.0         2000.0          3.0
# 9         1149.0             0.0             0.0         1926.0          1.0
#
#    Garage Area  SalePrice
# 0        440.0     115400
# 1        516.0      90000
# 2        544.0     141000
# 3        592.0     254000
# 4        576.0     155000
# 5        336.0     125000
# 6        632.0     194500
# 7        396.0     185000
# 8        839.0     235000
# 9        216.0     152000

# %%
(
    housing_data__float_test
      .describe(include="all")
      .transpose()
      .sort_values("count")
)
# Out:
#                  count           mean           std      min        25%  \
# Lot Frontage    2188.0      69.166819     23.356779     21.0      58.00
# Garage Yr Blt   2490.0    1978.185944     25.452647   1895.0    1961.00
# Mas Vnr Area    2614.0     101.887911    179.578232      0.0       0.00
# Bsmt Full Bath  2635.0       0.432258      0.525239      0.0       0.00
# Bsmt Half Bath  2635.0       0.058824      0.240130      0.0       0.00
# BsmtFin SF 2    2636.0      51.068665    172.521803      0.0       0.00
# Total Bsmt SF   2636.0    1045.179059    429.686089      0.0     792.00
# BsmtFin SF 1    2636.0     438.441199    449.602326      0.0       0.00
# Bsmt Unf SF     2636.0     555.669196    436.223188      0.0     218.00
# Garage Cars     2636.0       1.763278      0.760576      0.0       1.00
# Garage Area     2636.0     470.968134    212.816905      0.0     324.75
# SalePrice       2637.0  179986.230186  78309.251522  12789.0  129500.00
#
#                      50%        75%       max
# Lot Frontage        68.0      80.00     313.0
# Garage Yr Blt     1979.0    2002.00    2207.0
# Mas Vnr Area         0.0     164.00    1600.0
# Bsmt Full Bath       0.0       1.00       3.0
# Bsmt Half Bath       0.0       0.00       2.0
# BsmtFin SF 2         0.0       0.00    1526.0
# Total Bsmt SF      988.0    1290.25    6110.0
# BsmtFin SF 1       368.0     732.00    5644.0
# Bsmt Unf SF        464.5     797.25    2336.0
# Garage Cars          2.0       2.00       5.0
# Garage Area        480.0     576.00    1488.0
# SalePrice       160000.0  213000.00  745000.0

# %%
housing_data__float_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2637 entries, 0 to 2636
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Lot Frontage    2188 non-null   float64
#  1   Mas Vnr Area    2614 non-null   float64
#  2   BsmtFin SF 1    2636 non-null   float64
#  3   BsmtFin SF 2    2636 non-null   float64
#  4   Bsmt Unf SF     2636 non-null   float64
#  5   Total Bsmt SF   2636 non-null   float64
#  6   Bsmt Full Bath  2635 non-null   float64
#  7   Bsmt Half Bath  2635 non-null   float64
#  8   Garage Yr Blt   2490 non-null   float64
#  9   Garage Cars     2636 non-null   float64
#  10  Garage Area     2636 non-null   float64
#  11  SalePrice       2637 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 247.3 KB

# %%
# Drop Na or fill NA
housing_data__float_test.dropna(axis=0, inplace=True)
housing_data__float_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2033 entries, 0 to 2636
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Lot Frontage    2033 non-null   float64
#  1   Mas Vnr Area    2033 non-null   float64
#  2   BsmtFin SF 1    2033 non-null   float64
#  3   BsmtFin SF 2    2033 non-null   float64
#  4   Bsmt Unf SF     2033 non-null   float64
#  5   Total Bsmt SF   2033 non-null   float64
#  6   Bsmt Full Bath  2033 non-null   float64
#  7   Bsmt Half Bath  2033 non-null   float64
#  8   Garage Yr Blt   2033 non-null   float64
#  9   Garage Cars     2033 non-null   float64
#  10  Garage Area     2033 non-null   float64
#  11  SalePrice       2033 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 206.5 KB

# %%
(
    housing_data__float_test
      .describe(include="all")
      .transpose()
      .sort_values("count")
)
# Out:
#                  count           mean           std      min       25%  \
# Lot Frontage    2033.0      69.611904     23.403185     21.0      59.0
# Mas Vnr Area    2033.0     104.950812    183.982305      0.0       0.0
# BsmtFin SF 1    2033.0     435.367437    459.471209      0.0       0.0
# BsmtFin SF 2    2033.0      50.030005    168.679195      0.0       0.0
# Bsmt Unf SF     2033.0     575.289228    443.413756      0.0     231.0
# Total Bsmt SF   2033.0    1060.686670    436.855698      0.0     792.0
# Bsmt Full Bath  2033.0       0.424004      0.516704      0.0       0.0
# Bsmt Half Bath  2033.0       0.057550      0.237136      0.0       0.0
# Garage Yr Blt   2033.0    1977.728480     26.093979   1895.0    1959.0
# Garage Cars     2033.0       1.857354      0.667228      1.0       1.0
# Garage Area     2033.0     497.246434    190.145696    160.0     351.0
# SalePrice       2033.0  183745.530251  81566.772763  12789.0  130000.0
#
#                      50%       75%       max
# Lot Frontage        69.0      80.0     313.0
# Mas Vnr Area         0.0     169.0    1600.0
# BsmtFin SF 1       358.0     724.0    5644.0
# BsmtFin SF 2         0.0       0.0    1474.0
# Bsmt Unf SF        483.0     815.0    2336.0
# Total Bsmt SF      991.0    1313.0    6110.0
# Bsmt Full Bath       0.0       1.0       2.0
# Bsmt Half Bath       0.0       0.0       2.0
# Garage Yr Blt     1979.0    2003.0    2010.0
# Garage Cars          2.0       2.0       5.0
# Garage Area        482.0     583.0    1488.0
# SalePrice       160000.0  215000.0  745000.0

# %%
housing_data__float_test.corr() *1000
# Out:
#                 Lot Frontage  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  \
# Lot Frontage     1000.000000    222.444180    219.235514     31.789064
# Mas Vnr Area      222.444180   1000.000000    310.326236    -43.921366
# BsmtFin SF 1      219.235514    310.326236   1000.000000    -58.864469
# BsmtFin SF 2       31.789064    -43.921366    -58.864469   1000.000000
# Bsmt Unf SF       113.155096     92.422843   -487.853046   -250.209205
# Total Bsmt SF     357.713284    403.242788    533.863349     70.243934
# Bsmt Full Bath    118.205341    161.279130    643.038386    182.792377
# Bsmt Half Bath    -43.326193    -33.379771     69.358321    103.192696
# Garage Yr Blt      91.114677    271.761329    191.797184    -58.353305
# Garage Cars       316.999247    363.478521    217.463036    -54.672020
# Garage Area       376.225682    374.082563    278.636511    -30.607531
# SalePrice         353.583846    523.400508    434.639717    -15.075149
#
#                 Bsmt Unf SF  Total Bsmt SF  Bsmt Full Bath  Bsmt Half Bath  \
# Lot Frontage     113.155096     357.713284      118.205341      -43.326193
# Mas Vnr Area      92.422843     403.242788      161.279130      -33.379771
# BsmtFin SF 1    -487.853046     533.863349      643.038386       69.358321
# BsmtFin SF 2    -250.209205      70.243934      182.792377      103.192696
# Bsmt Unf SF     1000.000000     405.292275     -412.599670     -119.022764
# Total Bsmt SF    405.292275    1000.000000      328.114128       -8.015732
# Bsmt Full Bath  -412.599670     328.114128     1000.000000     -130.968642
# Bsmt Half Bath  -119.022764      -8.015732     -130.968642     1000.000000
# Garage Yr Blt    189.184997     371.219892      151.842412      -43.840222
# Garage Cars      248.845572     460.192055      154.109014      -53.840714
# Garage Area      222.307041     506.887289      187.593768      -50.672815
# SalePrice        191.868141     646.068132      288.550527      -60.585992
#
#                 Garage Yr Blt  Garage Cars  Garage Area    SalePrice
# Lot Frontage        91.114677   316.999247   376.225682   353.583846
# Mas Vnr Area       271.761329   363.478521   374.082563   523.400508
# BsmtFin SF 1       191.797184   217.463036   278.636511   434.639717
# BsmtFin SF 2       -58.353305   -54.672020   -30.607531   -15.075149
# Bsmt Unf SF        189.184997   248.845572   222.307041   191.868141
# Total Bsmt SF      371.219892   460.192055   506.887289   646.068132
# Bsmt Full Bath     151.842412   154.109014   187.593768   288.550527
# Bsmt Half Bath     -43.840222   -53.840714   -50.672815   -60.585992
# Garage Yr Blt     1000.000000   598.677596   586.652657   547.303332
# Garage Cars        598.677596  1000.000000   852.322280   657.322885
# Garage Area        586.652657   852.322280  1000.000000   637.670364
# SalePrice          547.303332   657.322885   637.670364  1000.000000

# %%
# Let's take a look at a correlation plot
# plt.figure(figsize=(15,15))
correlation_matrix = housing_data__float_test.corr()
sns.heatmap(data=correlation_matrix, annot=False, vmin=-1)
plt.title("Inital ")
plt.savefig("inital_corr.png", bbox_inches='tight')
plt.show();

# %%
correlation_matrix = housing_data__float_test.corr() >0.7
sns.heatmap(data=correlation_matrix, annot=True) ;
plt.savefig("inital_corr_high.png", bbox_inches='tight')
plt.show();

# %%
# Dropped column Garage Cars over 0.7 Corr
housing_data__float_test.drop(columns='Garage Cars', inplace=True)

# %%
correlation_matrix = housing_data__float_test.corr() >0.7
sns.heatmap(data=correlation_matrix, annot=True) ;

# %%
housing_float_clean = housing_data__float_test.copy()

# %%
housing_float_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2033 entries, 0 to 2636
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Lot Frontage    2033 non-null   float64
#  1   Mas Vnr Area    2033 non-null   float64
#  2   BsmtFin SF 1    2033 non-null   float64
#  3   BsmtFin SF 2    2033 non-null   float64
#  4   Bsmt Unf SF     2033 non-null   float64
#  5   Total Bsmt SF   2033 non-null   float64
#  6   Bsmt Full Bath  2033 non-null   float64
#  7   Bsmt Half Bath  2033 non-null   float64
#  8   Garage Yr Blt   2033 non-null   float64
#  9   Garage Area     2033 non-null   float64
#  10  SalePrice       2033 non-null   int64
# dtypes: float64(10), int64(1)
# memory usage: 190.6 KB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
plt.figure();
housing_float_clean.hist(bins=100, figsize=(12,8));
plt.tight_layout();

plt.savefig("housing_float_clean_hist.png");
plt.show();

# %%
sns.pairplot(housing_float_clean)

# %%
correlation_matrix = housing_float_clean.corr()
sns.heatmap(data=correlation_matrix, annot=False, vmin=-1) ;

# %%
plt.hist(housing_float_clean["SalePrice"], bins = 80, color="orange");
plt.xlabel("Sales Price($)", weight= "bold")
plt.ylabel("Frequency", weight= "bold")
plt.title('Housing Sales Price Frequency', weight= "bold", size=16)
plt.savefig("sales_price_freq.png", bbox_inches='tight')
plt.show();

# %% [markdown]
# ## Processing

# %% [markdown]
# ### Refining Predictor Choices

# %%
# Data frame of int values
housing_data_int = housing_data.select_dtypes(include=["int"])
housing_data_int.drop(columns='SalePrice', inplace= True)

# %%
# Combining Int and Float data frames
housing_data_int_float_df = pd.concat([housing_data_int,housing_float_clean], axis = 1,)

# %%
# drop NaN in Data frame
housing_data_int_float_df.dropna(axis=0, inplace= True)
housing_data_int_float_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2033 entries, 0 to 2636
# Data columns (total 37 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PID              2033 non-null   int64
#  1   MS SubClass      2033 non-null   int64
#  2   Lot Area         2033 non-null   int64
#  3   Overall Qual     2033 non-null   int64
#  4   Overall Cond     2033 non-null   int64
#  5   Year Built       2033 non-null   int64
#  6   Year Remod/Add   2033 non-null   int64
#  7   1st Flr SF       2033 non-null   int64
#  8   2nd Flr SF       2033 non-null   int64
#  9   Low Qual Fin SF  2033 non-null   int64
#  10  Gr Liv Area      2033 non-null   int64
#  11  Full Bath        2033 non-null   int64
#  12  Half Bath        2033 non-null   int64
#  13  Bedroom AbvGr    2033 non-null   int64
#  14  Kitchen AbvGr    2033 non-null   int64
#  15  TotRms AbvGrd    2033 non-null   int64
#  16  Fireplaces       2033 non-null   int64
#  17  Wood Deck SF     2033 non-null   int64
#  18  Open Porch SF    2033 non-null   int64
#  19  Enclosed Porch   2033 non-null   int64
#  20  3Ssn Porch       2033 non-null   int64
#  21  Screen Porch     2033 non-null   int64
#  22  Pool Area        2033 non-null   int64
#  23  Misc Val         2033 non-null   int64
#  24  Mo Sold          2033 non-null   int64
#  25  Yr Sold          2033 non-null   int64
#  26  Lot Frontage     2033 non-null   float64
#  27  Mas Vnr Area     2033 non-null   float64
#  28  BsmtFin SF 1     2033 non-null   float64
#  29  BsmtFin SF 2     2033 non-null   float64
#  30  Bsmt Unf SF      2033 non-null   float64
#  31  Total Bsmt SF    2033 non-null   float64
#  32  Bsmt Full Bath   2033 non-null   float64
#  33  Bsmt Half Bath   2033 non-null   float64
#  34  Garage Yr Blt    2033 non-null   float64
#  35  Garage Area      2033 non-null   float64
#  36  SalePrice        2033 non-null   float64
# dtypes: float64(11), int64(26)
# memory usage: 603.5 KB

# %%
corr = housing_data_int_float_df.corr()>0.7
plt.figure(figsize=(10, 8))
sns.heatmap(data=corr, annot=False, vmin=-1, xticklabels=True, yticklabels=True,linewidths=0.5)
plt.title("Correlation Matrix - High Correlations >0.7", weight= "bold", fontsize=14)
plt.tight_layout();
plt.savefig('int_float_corr_BD.png', bbox_inches='tight');
plt.show();

# %%
# Trial 3 testing Float and int dropping
cols_drop_t3 = ["Gr Liv Area", "1st Flr SF","Overall Qual","Half Bath","Bsmt Half Bath","Full Bath", "BsmtFin SF 2","Bsmt Unf SF", "Garage Yr Blt", "PID", "Mo Sold", "Misc Val", "Low Qual Fin SF", "Open Porch SF", "Yr Sold", "3Ssn Porch", "Enclosed Porch", "Fireplaces", "Lot Frontage","Screen Porch", "Wood Deck SF", "Pool Area", "Lot Area","Kitchen AbvGr", "Mas Vnr Area", "2nd Flr SF"]
housing_data_int_float_df = housing_data_int_float_df.drop(columns=cols_drop_t3)

# %%
housing_data_int_float_df.dtypes.value_counts()
# Out:
# int64      6
# float64    5
# Name: count, dtype: int64

# %%
housing_data_int_float_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2033 entries, 0 to 2636
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   MS SubClass     2033 non-null   int64
#  1   Overall Cond    2033 non-null   int64
#  2   Year Built      2033 non-null   int64
#  3   Year Remod/Add  2033 non-null   int64
#  4   Bedroom AbvGr   2033 non-null   int64
#  5   TotRms AbvGrd   2033 non-null   int64
#  6   BsmtFin SF 1    2033 non-null   float64
#  7   Total Bsmt SF   2033 non-null   float64
#  8   Bsmt Full Bath  2033 non-null   float64
#  9   Garage Area     2033 non-null   float64
#  10  SalePrice       2033 non-null   float64
# dtypes: float64(5), int64(6)
# memory usage: 190.6 KB

# %%
housing_data_int_float_df.describe().transpose().sort_index()
# Out:
#                  count           mean           std      min       25%  \
# Bedroom AbvGr   2033.0       2.843089      0.785243      0.0       2.0
# Bsmt Full Bath  2033.0       0.424004      0.516704      0.0       0.0
# BsmtFin SF 1    2033.0     435.367437    459.471209      0.0       0.0
# Garage Area     2033.0     497.246434    190.145696    160.0     351.0
# MS SubClass     2033.0      56.448598     42.018807     20.0      20.0
# Overall Cond    2033.0       5.583866      1.074936      1.0       5.0
# SalePrice       2033.0  183745.530251  81566.772763  12789.0  130000.0
# TotRms AbvGrd   2033.0       6.463847      1.543910      3.0       5.0
# Total Bsmt SF   2033.0    1060.686670    436.855698      0.0     792.0
# Year Built      2033.0    1971.982292     30.821346   1879.0    1953.0
# Year Remod/Add  2033.0    1984.906542     21.195777   1950.0    1965.0
#
#                      50%       75%       max
# Bedroom AbvGr        3.0       3.0       6.0
# Bsmt Full Bath       0.0       1.0       2.0
# BsmtFin SF 1       358.0     724.0    5644.0
# Garage Area        482.0     583.0    1488.0
# MS SubClass         50.0      70.0     190.0
# Overall Cond         5.0       6.0       9.0
# SalePrice       160000.0  215000.0  745000.0
# TotRms AbvGrd        6.0       7.0      12.0
# Total Bsmt SF      991.0    1313.0    6110.0
# Year Built        1974.0    2003.0    2010.0
# Year Remod/Add    1994.0    2005.0    2010.0

# %%
plt.figure();
housing_data_int_float_df.hist(bins=100, figsize=(20, 15))
plt.tight_layout();
plt.savefig('final_variable_hist.png', bbox_inches='tight');
plt.show();

# %%
corr = housing_data_int_float_df.corr()<0.7
plt.figure(figsize=(10, 8))
sns.heatmap(data=corr, annot=False, vmin=-1, xticklabels=True, yticklabels=True,linewidths=0.5)
plt.title("Correlation Matrix - Chosen Predictors >0.7", weight= "bold", fontsize=14)
plt.tight_layout();
plt.savefig('int_float_corr_AD.png', bbox_inches='tight');
plt.show();

# %%
corr = housing_data_int_float_df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(data=corr, annot=False, vmin=-1, xticklabels=True, yticklabels=True,linewidths=0.5)
plt.title("Correlation Matrix", weight= "bold", fontsize=14)
plt.tight_layout();
plt.savefig('int_float_corr_AD.png', bbox_inches='tight');
plt.show();

# %% [markdown]
# ---
#
#
# ### Regularization - Linear Regression

# %%
# First we will break up our data into training and testing sets
X_linear = housing_data_int_float_df.drop(["SalePrice"], axis = 1).copy()
y_linear = housing_data_int_float_df['SalePrice']


# Specify values of alpha we want to try
alph = [ 1e-12, 1e-10, 1e-8, 1e-4, 1e-3, 1e-2, 1e-1,20,50,120,150,200, 500]

# Create empty list to hold results
results_alpha = []

for i in alph:
  # Calculate CV RMSE
  n = 200
  results = np.zeros(n)

  for idx in range(n):
    # Create the model
    my_fit_linear = Lasso(alpha = i, tol = .01, max_iter=10_000); # Looping through alpha

    # Train, test split
    X_train, X_test, y_train, y_test = train_test_split(X_linear, y_linear, test_size=0.25)

    # Standard scale only training features
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)

    # Scale testing features
    X_test = scaler.transform(X_test)

    # Fit regression
    my_fit_linear.fit(X_train, y_train)

    # Predict
    y_pred = my_fit_linear.predict(X_test)

    # Calculate and record performance metric
    results[idx] = np.sqrt(mean_squared_error(y_test,y_pred))

  results_alpha.append(results.mean())

results_df = pd.DataFrame({'Alpha': alph, 'RMSE': results_alpha})

results_df.sort_values( by = 'RMSE' )
alpha = results_df.sort_values( by = 'RMSE' )["Alpha"].iloc[0]

print(f"Alpha: {alpha}")

# %%capture --no-stdout
# Perform CV
n = 500
results = np.zeros(n)

for idx in range(n):
  # Train, test split
  X_train, X_test, y_train, y_test = train_test_split(X_linear, y_linear, test_size=0.25)

  # Standard scale only training features
  scaler = StandardScaler()
  scaler.fit(X_train)
  X_train = scaler.transform(X_train)

  # Scale testing features
  X_test = scaler.transform(X_test)

  # Create the model
  model = Lasso(alpha = alpha, tol = .01, max_iter=10000)

  # Fit regression
  model.fit(X_train, y_train)

  # Predict
  y_pred = model.predict(X_test)

  # Calculate and record performance metric
  results[idx] = np.sqrt(mean_squared_error(y_test,y_pred))

print(f"CV RMSE: {results.mean().round(2)}")
# RMSPE
rmspe_housing_float = np.sqrt(np.mean(np.square((y_test - y_pred) / y_test))) * 100
print(f"RMSPE for Linear Regression: {rmspe_housing_float:.4f}%")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.777e+11, tolerance: 1.003e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.005e+12, tolerance: 1.013e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.235e+11, tolerance: 9.988e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.903e+11, tolerance: 1.014e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.459e+11, tolerance: 9.662e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.013e+11, tolerance: 9.976e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.473e+11, tolerance: 1.024e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.535e+11, tolerance: 1.009e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.294e+11, tolerance: 9.817e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.937e+11, tolerance: 1.003e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.412e+11, tolerance: 1.012e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.176e+12, tolerance: 1.018e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.079e+11, tolerance: 9.963e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.706e+11, tolerance: 9.599e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.009e+12, tolerance: 1.030e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.880e+11, tolerance: 1.041e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.303e+11, tolerance: 9.798e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.082e+12, tolerance: 1.020e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.441e+11, tolerance: 1.012e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.042e+12, tolerance: 9.653e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.146e+12, tolerance: 1.019e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.177e+11, tolerance: 1.028e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.772e+11, tolerance: 1.045e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.282e+11, tolerance: 9.726e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.458e+11, tolerance: 1.021e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.318e+11, tolerance: 9.658e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.884e+11, tolerance: 1.030e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.856e+11, tolerance: 1.010e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.754e+11, tolerance: 9.562e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.065e+11, tolerance: 1.040e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.609e+11, tolerance: 9.921e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.406e+11, tolerance: 9.888e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.921e+11, tolerance: 1.012e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.500e+11, tolerance: 9.926e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.774e+11, tolerance: 9.677e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.000e+12, tolerance: 1.031e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.112e+12, tolerance: 1.082e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.047e+12, tolerance: 1.029e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.950e+11, tolerance: 1.036e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.165e+12, tolerance: 1.018e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.615e+11, tolerance: 9.378e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.709e+11, tolerance: 1.039e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.726e+11, tolerance: 9.826e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.417e+11, tolerance: 9.927e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.571e+11, tolerance: 1.037e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.049e+12, tolerance: 9.710e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.984e+11, tolerance: 1.041e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.658e+11, tolerance: 1.049e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.053e+12, tolerance: 1.007e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.942e+11, tolerance: 9.699e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.128e+12, tolerance: 1.005e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.738e+11, tolerance: 1.070e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.090e+12, tolerance: 1.043e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.009e+12, tolerance: 1.043e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.632e+11, tolerance: 1.045e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.689e+11, tolerance: 1.001e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.172e+12, tolerance: 1.077e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.561e+11, tolerance: 9.772e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.023e+11, tolerance: 1.089e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.071e+11, tolerance: 1.006e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.274e+11, tolerance: 1.070e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.992e+11, tolerance: 1.068e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.165e+12, tolerance: 1.017e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.907e+11, tolerance: 1.068e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.128e+12, tolerance: 1.047e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.861e+11, tolerance: 1.047e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.039e+12, tolerance: 1.038e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.311e+11, tolerance: 1.010e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.617e+11, tolerance: 1.054e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.207e+12, tolerance: 1.103e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.114e+12, tolerance: 1.068e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.712e+11, tolerance: 9.850e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.696e+11, tolerance: 1.028e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.185e+11, tolerance: 9.648e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.206e+12, tolerance: 1.024e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.113e+12, tolerance: 1.009e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.061e+12, tolerance: 9.619e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.568e+11, tolerance: 1.028e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.622e+11, tolerance: 1.005e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.088e+12, tolerance: 9.572e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.579e+11, tolerance: 1.020e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.661e+11, tolerance: 1.000e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.041e+12, tolerance: 1.004e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.126e+11, tolerance: 9.614e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.392e+11, tolerance: 1.002e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.234e+12, tolerance: 1.088e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.891e+11, tolerance: 9.981e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.182e+12, tolerance: 1.022e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.190e+11, tolerance: 1.005e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.301e+12, tolerance: 1.035e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.233e+12, tolerance: 1.044e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.069e+11, tolerance: 1.040e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.060e+12, tolerance: 9.912e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.459e+11, tolerance: 1.015e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.882e+11, tolerance: 1.013e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.788e+11, tolerance: 9.680e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.164e+11, tolerance: 9.885e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.222e+11, tolerance: 1.013e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.147e+11, tolerance: 9.900e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.204e+12, tolerance: 1.034e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.886e+11, tolerance: 9.923e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.929e+11, tolerance: 1.075e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.164e+12, tolerance: 1.023e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.854e+11, tolerance: 9.863e+10
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.615e+11, tolerance: 1.042e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.826e+11, tolerance: 1.017e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.137e+12, tolerance: 1.041e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.953e+11, tolerance: 1.096e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.080e+12, tolerance: 1.042e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.250e+11, tolerance: 1.017e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.649e+11, tolerance: 1.020e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.286e+12, tolerance: 1.072e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.194e+12, tolerance: 1.052e+11
#   model = cd_fast.enet_coordinate_descent(
# Alpha: 500.0
# CV RMSE: 43234.88
# RMSPE for Linear Regression: 30.6369%

# %%
# Generate figure of predicted vs actual results
plt.figure(figsize=(10,8));
plt.scatter(y_test, y_pred);
p1 = max(y_pred.max(), y_test.max())
plt.plot([0, p1],[0, p1], c='red')
plt.ylim(0,825000)
plt.xlim(0,825000)
plt.title('Linear Regression: Predicted  vs True Values', weight='bold', fontsize=14)
plt.xlabel('True Values($)', weight='bold', fontsize=12)
plt.ylabel('Predicted Values($)', weight='bold', fontsize=12)
plt.grid(True, linestyle=':', alpha=0.7)
plt.savefig("linear_pred_true_scatter.png", bbox_inches='tight')
plt.show();

# %%
plt.figure(figsize=(10,8));
residuals = y_test - y_pred
plt.scatter(x=y_pred, y=residuals)
plt.axhline(y=0, color='red', linestyle='--', linewidth=1.5)
plt.title('Linear Regression: Residuals vs. Predicted', weight='bold', fontsize=14)
plt.xlabel('Predicted Values($)', weight='bold', fontsize=12)
plt.ylabel('Residuals', weight='bold', fontsize=12)
plt.grid(True, linestyle=':', alpha=0.7)
plt.savefig("linear_residuals_pred.png", bbox_inches='tight')
plt.show();

# %%
# Plot model coefficients
model_results = pd.DataFrame()
model_results['Predictor'] = X_linear.columns
model_results['Linear'] = model.coef_
model_results.sort_values( by = ["Linear"], ascending = False ).plot(
    x = 'Predictor',
    kind = 'bar',
    figsize = (20,5)
    )
plt.grid()

# %% [markdown]
# ---
#
#
# ### Regularization - Ridge Regression

# %%
housing_data_int_float_df_bak = housing_data_int_float_df.copy()
housing_data_int_float_df = housing_data_int_float_df_bak.copy()

# %%
# First we will break up our data into training and testing sets
X_ridge = housing_data_int_float_df.drop(["SalePrice"], axis = 1).copy()
y_ridge = housing_data_int_float_df['SalePrice']

# Specify values of alpha we want to try
alph = [1e-10, 1e-8, 1e-4, 1e-3, 1e-2, 1e-1,1,5,10,20,50,70,90,120,150,180,200, 300, 500]

# Create empty list to hold results
results_alpha = []

for i in alph:
  # Calculate CV RMSE
  n = 200
  results = np.zeros(n)

  for idx in range(n):
    # Create the model
    my_fit_ridge = Ridge(alpha = i, tol = .01, max_iter=10_000); # Looping through alpha

    # Train, test split
    X_train, X_test, y_train, y_test = train_test_split(X_ridge, y_ridge, test_size=0.25)

    # Standard scale only training features
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)

    # Scale testing features
    X_test = scaler.transform(X_test)

    # Fit regression
    my_fit_ridge.fit(X_train, y_train)

    # Predict
    y_pred = my_fit_ridge.predict(X_test)

    # Calculate and record performance metric
    results[idx] = np.sqrt(mean_squared_error(y_test,y_pred))

  results_alpha.append(results.mean())

results_df = pd.DataFrame({'Alpha': alph, 'RMSE': results_alpha})

results_df.sort_values( by = 'RMSE' )
alpha = results_df.sort_values( by = 'RMSE' )["Alpha"].iloc[0]

print(f"Alpha: {alpha}")

# %%capture --no-stdout
# Perform CV
n = 500
results = np.zeros(n)

for idx in range(n):
  # Train, test split
  X_train, X_test, y_train, y_test = train_test_split(X_ridge, y_ridge, test_size=0.25)

  # Standard scale only training features
  scaler = StandardScaler()
  scaler.fit(X_train)
  X_train = scaler.transform(X_train)

  # Scale testing features
  X_test = scaler.transform(X_test)

  # Create the model
  model = Ridge(alpha = alpha, tol = .01, max_iter=10000)

  # Fit regression
  model.fit(X_train, y_train)

  # Predict
  y_pred = model.predict(X_test)

  # Calculate and record performance metric
  results[idx] = np.sqrt(mean_squared_error(y_test,y_pred))

print(f"CV RMSE: {results.mean().round(2)}")
# RMSPE
rmspe_housing_float = np.sqrt(np.mean(np.square((y_test - y_pred) / y_test))) * 100
print(f"RMSPE for Ridge Regression: {rmspe_housing_float:.4f}%")
# Out:
# Alpha: 1e-10
# CV RMSE: 43258.1
# RMSPE for Ridge Regression: 23.6645%

# %%
# Generate figure of predicted vs actual results
plt.figure(figsize=(10,8));
plt.scatter(y_test, y_pred, color="orange");
p1 = max(y_pred.max(), y_test.max())
plt.plot([0, p1],[0, p1], c='red')
plt.ylim(0,825000)
plt.xlim(0,825000)
plt.title('Ridge Regression: Predicted  vs True Values', weight='bold', fontsize=14)
plt.xlabel('True Values($)', weight='bold', fontsize=12)
plt.ylabel('Predicted Values($)', weight='bold', fontsize=12)
plt.grid(True, linestyle=':', alpha=0.7)
plt.savefig("ridge_pred_true_scatter.png", bbox_inches='tight')
plt.show();

# %%
plt.figure(figsize=(10,8));
residuals = y_test - y_pred
plt.scatter(x=y_pred, y=residuals, color="Orange")
plt.axhline(y=0, color='red', linestyle='--', linewidth=1.5)
plt.title('Ridge Regression: Residuals vs. Predicted', weight='bold', fontsize=14)
plt.xlabel('Predicted Values($)', weight='bold', fontsize=12)
plt.ylabel('Residuals($)', weight='bold', fontsize=12)
plt.grid(True, linestyle=':', alpha=0.7)
plt.savefig("ridge_residuals_pred.png", bbox_inches='tight')
plt.show();

# %%
# Add ridge regression results to data frame we created earlier
model_results['Ridge'] = model.coef_
model_results.sort_values( by = ["Ridge"], ascending = False ).plot(
    x = 'Predictor',
    kind = 'bar',
    figsize = (20,5)
    )
plt.grid()

# %% [markdown]
# ### Regularization - Lasso Reggression

# %%
# First we will break up our data into training and testing sets
X_lasso = housing_data_int_float_df.drop(["SalePrice"], axis = 1).copy()
y_lasso = housing_data_int_float_df['SalePrice']


# Specify values of alpha we want to try
alph = [1e-10, 1e-8, 1e-4, 1e-3, 1e-2, 1e-1,20,50,70,90,120,150,180,200, 300, 500]

# Create empty list to hold results
results_alpha = []

for i in alph:
  # Calculate CV RMSE
  n = 200
  results = np.zeros(n)

  for idx in range(n):
    # Create the model
    my_fit_lasso = Lasso(alpha = i, tol = .01, max_iter=10_000); # Looping through alpha

    # Train, test split
    X_train, X_test, y_train, y_test = train_test_split(X_lasso, y_lasso, test_size=0.25)

    # Standard scale only training features
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)

    # Scale testing features
    X_test = scaler.transform(X_test)

    # Fit regression
    my_fit_lasso.fit(X_train, y_train)

    # Predict
    y_pred = my_fit_lasso.predict(X_test)

    # Calculate and record performance metric
    results[idx] = np.sqrt(mean_squared_error(y_test,y_pred))

  results_alpha.append(results.mean())

results_df = pd.DataFrame({'Alpha': alph, 'RMSE': results_alpha})

results_df.sort_values( by = 'RMSE' )
alpha = results_df.sort_values( by = 'RMSE' )["Alpha"].iloc[0]

print(f"Alpha: {alpha}")

# %%capture --no-stdout
# Perform CV
n = 500
results = np.zeros(n)

for idx in range(n):
  # Train, test split
  X_train, X_test, y_train, y_test = train_test_split(X_lasso, y_lasso, test_size=0.25)

  # Standard scale only training features
  scaler = StandardScaler()
  scaler.fit(X_train)
  X_train = scaler.transform(X_train)

  # Scale testing features
  X_test = scaler.transform(X_test)

  # Create the model
  model = Lasso(alpha = alpha, tol = .01, max_iter=10000)

  # Fit regression
  model.fit(X_train, y_train)

  # Predict
  y_pred = model.predict(X_test)

  # Calculate and record performance metric
  results[idx] = np.sqrt(mean_squared_error(y_test,y_pred))

print(f"CV RMSE: {results.mean().round(2)}")
# RMSPE
rmspe_housing_float = np.sqrt(np.mean(np.square((y_test - y_pred) / y_test))) * 100
print(f"RMSPE for Lasso: {rmspe_housing_float:.4f}%")
# Out:
# Alpha: 180.0
# CV RMSE: 43293.72
# RMSPE for Lasso: 25.0585%

# %%
# Generate figure of predicted vs actual results
plt.figure(figsize=(10,8));
plt.scatter(y_test, y_pred, color= 'green');
p1 = max(y_pred.max(), y_test.max())
plt.plot([0, p1],[0, p1], c='red')
plt.ylim(0,825000)
plt.xlim(0,825000)
plt.title('Lasso Regression: Predicted  vs True Values', weight='bold', fontsize=14)
plt.xlabel('True Values($)', weight='bold', fontsize=12)
plt.ylabel('Predicted Values($)', weight='bold', fontsize=12)
plt.grid(True, linestyle=':', alpha=0.7)
plt.savefig("lasso_pred_true_scatter.png", bbox_inches='tight')
plt.show();

# %%
plt.figure(figsize=(10,8));
residuals = y_test - y_pred
plt.scatter(x=y_pred, y=residuals, color="Green")
plt.axhline(y=0, color='red', linestyle='--', linewidth=1.5)
plt.title('Lasso Regression: Residuals vs. Predicted', weight='bold', fontsize=14)
plt.xlabel('Predicted Values($)', weight='bold', fontsize=12)
plt.ylabel('Residuals($)', weight='bold', fontsize=12)
plt.grid(True, linestyle=':', alpha=0.7)
plt.savefig("lasso_residuals_pred.png", bbox_inches='tight')
plt.show();

# %%
# Plot model coefficients
model_results["Lasso"] = model.coef_
model_results.sort_values( by = ["Lasso"], ascending = False ).plot(
    x = "Predictor",
    kind = 'bar',
    figsize = (20,5)
    )
plt.title("Comparison of Predictor Coefficients Across Regression Models", weight= "bold", fontsize= 14)
plt.xlabel("Predictors", weight ="bold", fontsize= 12)
plt.ylabel("Coefficients", weight ="bold", fontsize= 12)
plt.grid()
plt.savefig("regression_model_coefficients_comparison.png", bbox_inches='tight')
plt.show();

# %%
model_results
# Out:
#         Predictor        Linear         Ridge         Lasso
# 0     MS SubClass   -275.499727  -2916.789823  -2343.966093
# 1    Overall Cond   6256.419672   6907.243410   6621.584818
# 2      Year Built  14209.731395  18502.055198  17590.371943
# 3  Year Remod/Add  12499.042488  11442.100328  12176.840948
# 4   Bedroom AbvGr  -7355.421987 -10988.830284 -10549.009177
# 5   TotRms AbvGrd  32611.095769  34690.637792  33678.050754
# 6    BsmtFin SF 1  15091.512717   8537.516565   8526.750315
# 7   Total Bsmt SF  22929.808377  18949.782355  19855.535333
# 8  Bsmt Full Bath      0.000000   3265.090568   2424.952114
# 9     Garage Area  15475.409891  14239.765322  15298.137031

# %% [markdown]
# ## Data Visualization/Communication of Results
